# %%
#Student Marks
student_name = input("Student: ")
math_marks = float(input("Math: "))
english_marks = float(input("English: "))
python_marks = float(input("Python: "))

total = math_marks + english_marks + python_marks

marks = (math_marks, english_marks, python_marks)
#highest_mark = marks[0]
#lowest_mark = marks[0]

#for mark in marks:
    #if mark > highest_mark:
        #highest_mark = mark
    #if mark < lowest_mark:
        #lowest_mark = mark

avg = total / len(marks)
highest_mark = max(marks)
lowest_mark = min(marks)
print("Student: ", student_name)
print("Total: ", total)
print("Average: ", avg)
print("Highest: ", highest_mark)
print("Lowest: ", lowest_mark)
# Out:
# Student:  Omar
# Total:  270.0
# Average:  90.0
# Highest:  95.0
# Lowest:  85.0

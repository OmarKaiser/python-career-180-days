# %%
age = 20

if age >= 18: print("You are an adult.")
else: print("You are a minor.")
# Out:
# You are an adult.

# %%
marks = 75

if marks >= 80: print("A+")
elif marks >= 70: print("A")
elif marks >= 60: print("A-")
else: print("Needs improvement")
# Out:
# A

# %%
x = 10

print(x == 10)
print(x != 10)
print(x > 5)
print(x < 5)
print(x >= 10)
print(x <= 10)
# Out:
# True
# False
# True
# False
# True
# True

# %%
age = 25
has_id = True

if age >=18 and has_id: print("Access granted")
# Out:
# Access granted

# %%
has_email = True
has_phone = False

if has_email or has_phone: print("Contact information available")
# Out:
# Contact information available

# %%
is_banned = False

if not is_banned: print("Account active")

# %%
age = int(input("Enter your age: "))
monthly_income = int(input("Enter your monthly income: "))

if age < 18: 
    print("You are under 18.")

elif monthly_income >= 20000: 
    print("You meet the criteria.")

else: 
    print("You are an adult, but your income is below the required amount.")
# Out:
# You are an adult, but your income is below the required amount.

# %%
num1 = int(input("First Number: "))
num2 = int(input("Second Number: "))

sum = num1 + num2
diff  = num1 - num2
prod = num1 * num2
div = num1 / num2

print(sum)
print(diff)
print(prod)
print(float(div))
# Out:
# 73
# 17
# 1260
# 1.6071428571428572
